# %% [markdown]
# # **Importing dependancies** #

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **A sample line chart**

# %%
L1 = [1,2,3,4]
L2 = [10, 25, 32, 58]

#used when a particular variable changes againts the time.

plt.plot(L1, L2)
plt.show()

# %% [markdown]
# **Adding a title and axis name**

# %%
L1 = [1,2,3,4]
L2 = [10, 25, 32, 58]

#used when a particular variable changes againts the time.

plt.plot(L1, L2)
plt.title("Learning line chart")
plt.xlabel("L2 = Time")
plt.ylabel("L1 = Dependant variable")
plt.show()

# %% [markdown]
# **Changing the Size of the chart**

# %%
L1 = [1,2,3,4]
L2 = [10, 25, 32, 58]

#used when a particular variable changes againts the time.
plt.figure(figsize=(6,3))  #figsize should be given before the titile and labeling
plt.plot(L1, L2)
plt.title("Learning line chart")
plt.xlabel("L2 = Time")
plt.ylabel("L1 = Dependant variable")
plt.show()

# %% [markdown]
# **Change the colors**

# %%
L1 = [1,2,3,4]
L2 = [10, 25, 32, 58]

#used when a particular variable changes againts the time.
plt.figure(figsize=(6,3))  #figsize should be given before the titile and labeling
plt.plot(L1, L2, "r*")   #color as third arguement
plt.title("Learning line chart")
plt.xlabel("L2 = Time")
plt.ylabel("L1 = Dependant variable")
plt.show()

# %% [markdown]
# **Plotting multiple charts together**

# %%
x = np.arange(10)
y1 =  x+5
y2 = x**2

plt.figure(figsize=(6,3))  
plt.plot(x, y1, "red",x,y2, "green")   #important : can remove the 2nd "x" and still get the correct output
plt.title("Learning line chart")
plt.xlabel("Time")
plt.ylabel("Dependant variables")
plt.show()

# %% [markdown]
# # **Subplots** #

# %% [markdown]
# # **First method** #

# %%
x = np.arange(10)
y1 =  x+5
y2 = x**2
plt.figure(figsize=(6,3)) 

plt.subplot(1,2,1) #1 row 2 column, 1st chart
plt.plot(x, y1, "red")

plt.subplot(1,2,2) #1 row 2 column, 2st chart
plt.plot(x, y2, "green")
plt.show()

# %% [markdown]
# **2 rows and 1 column**

# %%
x = np.arange(10)
y1 =  x+5
y2 = x**2
plt.figure(figsize=(6,3)) 

plt.subplot(2,1,1) #2 row 1 column, 1st chart
plt.plot(x, y1, "red")

plt.subplot(2,1,2) #2 row 1 column, 2st chart
plt.plot(x, y2, "green")
plt.show()

# %% [markdown]
# # **Second method** #

# %%
x = np.arange(10)
y1 =  x+5
y2 = x**2
y3 = -x
y4 = np.sqrt(x)
plt.figure(figsize=(6,3)) 

plt.subplot(2,2,1) #2 row 2 column, 1st chart
plt.plot(x, y1, "red")

plt.subplot(2,2,2) #2 row 2 column, 2nd chart
plt.plot(x, y2, "green")

plt.subplot(2,2,3) #2 row 2 column, 3rd chart
plt.plot(x, y3, "blue")

plt.subplot(2,2,4) #2 row 2 column, 4th chart
plt.plot(x, y4, "yellow")

plt.show()

# %% [markdown]
# **Another way of doing above task**

# %%
x = np.arange(10)
y1 =  x+5
y2 = x**2
y3 = -x
y4 = np.sqrt(x)

fig,sfigs = plt.subplots(nrows = 2, ncols = 2, figsize=(6,3))

sfigs[0,0].plot(x,y1,"r")
sfigs[0,0].set_title("First chart")
sfigs[0,0].set_xlabel("Time")
sfigs[0,0].set_ylabel("Dependant variable")

sfigs[0,1].plot(x,y2,"g")
sfigs[0,1].set_title("Second chart")

sfigs[1,0].plot(x,y3,"k")
sfigs[1,0].set_title("Third chart")

sfigs[1,1].plot(x,y4,"yellow")
sfigs[1,1].set_title("Fourth chart")


plt.show()

# %%
df = pd.DataFrame({
    "Year": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000],
    "Weight": [76, 64, 65, 70, 78, 79, 75, 74, 69, 68, 65],
    "Height": [167, 168, 168, 168, 169, 170, 171, 171, 172, 173, 174]
})

df
# Out:
#     Year  Weight  Height
# 0   1990      76     167
# 1   1991      64     168
# 2   1992      65     168
# 3   1993      70     168
# 4   1994      78     169
# 5   1995      79     170
# 6   1996      75     171
# 7   1997      74     171
# 8   1998      69     172
# 9   1999      68     173
# 10  2000      65     174

# %%
plt.plot(df["Year"], df["Weight"],"g")
plt.xlabel("Year")
plt.ylabel("Weight")
plt.title("Weight againts time")
plt.show()

# %% [markdown]
# #  **Area Charts**  #

# %%
L1 = [1,2,3,4]
L2 = [10, 25, 32, 58]
plt.figure(figsize=(6,3)) 
plt.fill_between(L1,L2)
plt.show()

# %%
plt.figure(figsize=(6,3)) 
plt.plot(df["Year"], df["Weight"])
plt.xlabel("Year")
plt.ylabel("Weight")
plt.title("Weight againts time")
plt.fill_between(df["Year"], df["Weight"])
plt.show()

# %%
df = pd.DataFrame({
    "Year": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000],
    "Weight": [76, 64, 65, 70, 78, 79, 75, 74, 69, 68, 65],
    "Height": [167, 168, 168, 168, 169, 170, 171, 171, 172, 173, 174]
})

df
# Out:
#     Year  Weight  Height
# 0   1990      76     167
# 1   1991      64     168
# 2   1992      65     168
# 3   1993      70     168
# 4   1994      78     169
# 5   1995      79     170
# 6   1996      75     171
# 7   1997      74     171
# 8   1998      69     172
# 9   1999      68     173
# 10  2000      65     174

# %%
plt.figure(figsize=(6,3)) 
plt.stackplot(df["Year"], df["Weight"],df["Height"])
plt.show()

# %% [markdown]
# #  **Histogram**  #

# %%
data = np.random.random(1000)
plt.figure(figsize=(6,3)) 
plt.hist(data,20, color="red", edgecolor="black")  #20 bins
plt.show()

# %%
default = pd.read_csv("/Users/kanishkarathnayake/Downloads/Arc Downloads/default.csv")
default.head()
# Out:
#    Gender  Loan.Offered        Job  Work.Exp  Credit.Score  EMI.Ratio Status  \
# 0    Male             0  unskilled        14            86        3.0     No
# 1  Female             1    skilled        15            94        3.0     No
# 2    Male             0  unskilled        16            86        3.0     No
# 3  Female             1    skilled        13            94        3.0     No
# 4    Male             1    skilled        12            85        3.3     No
#
#   Credit.History  Own house   Purpose  Dependents
# 0           poor          1  personal           2
# 1           poor          1  personal           3
# 2           poor          1  personal           2
# 3           poor          1  personal           3
# 4           poor          1  personal           2

# %%
plt.figure(figsize = (6,3))
plt.hist(default["Credit.History"],10)
plt.show()

# %%
plt.figure(figsize = (6,3))
plt.hist(default["Work.Exp"],10)
plt.show()

# %% [markdown]
# # **Boxplots** #

# %%
data = np.random.random(1000)

# %%
plt.boxplot(data)
plt.show()

# %%
plt.boxplot(default["Credit.Score"])
plt.show()

# %% [markdown]
# # **Categorical Data** #

# %% [markdown]
# # **Bar Graphs** #

# %%
Gender = ["Male", "Female"]
Number_of_Students=[45,75]

plt.bar(Gender,Number_of_Students,color = "red")
plt.show()

# %%
default.head()
# Out:
#    Gender  Loan.Offered        Job  Work.Exp  Credit.Score  EMI.Ratio Status  \
# 0    Male             0  unskilled        14            86        3.0     No
# 1  Female             1    skilled        15            94        3.0     No
# 2    Male             0  unskilled        16            86        3.0     No
# 3  Female             1    skilled        13            94        3.0     No
# 4    Male             1    skilled        12            85        3.3     No
#
#   Credit.History  Own house   Purpose  Dependents
# 0           poor          1  personal           2
# 1           poor          1  personal           3
# 2           poor          1  personal           2
# 3           poor          1  personal           3
# 4           poor          1  personal           2

# %%
default["Gender"].value_counts()
# Out:
# Gender
# Male      548
# Female    233
# Name: count, dtype: int64

# %%
d1 = pd.DataFrame(default["Gender"].value_counts())
d1.reset_index(inplace = True)
d1
# Out:
#    Gender  count
# 0    Male    548
# 1  Female    233

# %%
plt.bar(d1["Gender"], d1["count"])
plt.show()

# %% [markdown]
# # **Different colors for bars** #

# %%
Gender = ["Male", "Female"]
Number_of_Students=[45,75]

plt.bar(Gender,Number_of_Students,color = ["red", "yellow"])
plt.show()

# %% [markdown]
# # **Horizontal bar graphs** #

# %%
Gender = ["Male", "Female"]
Number_of_Students=[45,75]

plt.barh(Gender,Number_of_Students,color = ["red", "yellow"])
plt.show()

# %% [markdown]
# # **Pie charts** #

# %%
Gender = ["Male", "Female"]
Number_of_Students=[45,75]

plt.pie(Number_of_Students, labels = Gender, autopct = "%d")
plt.legend(title="Gender")
plt.axis("equal")
plt.show()

# %%
Gender = ["Male", "Female"]
Number_of_Students=[45,75]

plt.pie(Number_of_Students, labels = Gender, autopct = "%.2f%%")
plt.legend(title="Gender")
plt.axis("equal")
plt.show()

# %% [markdown]
# # **Pie Charts with Explodes** #

# %%
Gender = ["Male", "Female"]
Number_of_Students=[45,75]

plt.pie(Number_of_Students, labels = Gender, autopct = "%.2f%%", explode = [0, 0.1])
plt.legend(title="Gender")
plt.axis("equal")
plt.show()

# %%
Name = ["John", "Kane", "Anne", "Jane"]
Company_share = [20, 15, 35, 30]

plt.pie(Company_share, labels=Name, autopct="%.2f%%", explode=[0, 0.1, 0.2, 0.3])
plt.legend(title="Gender")
plt.axis("equal")
plt.title("A pie chart")
plt.show()
